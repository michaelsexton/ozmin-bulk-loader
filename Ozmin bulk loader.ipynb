# %%
import pandas as pd
import cx_Oracle
import ozmin_loader

# %%
nickel_resources = pd.read_excel('nickel/Ni Reserves and Resources 2017.xlsx')

# %%
for index, row in nickel_resources.iterrows():
    deposit_eno = row["DEPOSIT_ENO"]
    deposit = get_or_create_deposit(eno)
# Out:
# DEPOSIT_ENO                                       336131
# DEPOSIT_NAME                                     Barbara
# Company                        Syndicated Metals Limited
# ZONE_NAME                                        Barbara
# Date                                 2014-07-18 00:00:00
# PRV, Mt                                              NaN
# Ni, %                                                NaN
# Co, %                                                NaN
# PRB, Mt                                              NaN
# Ni, %.1                                              NaN
# Co, %.1                                              NaN
# MRS, Mt                                              NaN
# Ni, %.2                                              NaN
# Co, %.2                                              NaN
# IND, Mt                                             3.25
# Ni, %.3                                              NaN
# Co, %.3                                            0.028
# IFR, Mt                                             1.49
# Ni, %.4                                              NaN
# Co, %.4                                            0.037
# Update status                                        NaN
# Reference           Syndicated Metals 2016 Annual Report
# My Comment                                           NaN
# OPERATING_STATUS                           historic mine
# STATE                                                QLD
# COMMODIDS                               Cu, (Au, Ag, Co)
# ZONE_ENO                                          534778
# Name: 0, dtype: object
# DEPOSIT_ENO                                      NaN
# DEPOSIT_NAME                        Beautiful Sunday
# Company                            Western Areas Ltd
# ZONE_NAME                           Beautiful Sunday
# Date                             2016-06-30 00:00:00
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                         0.48
# Ni, %.3                                          1.4
# Co, %.3                                          NaN
# IFR, Mt                                          NaN
# Ni, %.4                                          NaN
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                                 NaN
# STATE                                             WA
# COMMODIDS                                         Ni
# ZONE_ENO                                         NaN
# Name: 1, dtype: object
# DEPOSIT_ENO                                            333811
# DEPOSIT_NAME                                        Beta Hunt
# Company                                     ROYAL NICKEL CORP
# ZONE_NAME                                       Beta (Nickel)
# Date                                      2016-02-01 00:00:00
# PRV, Mt                                                   NaN
# Ni, %                                                     NaN
# Co, %                                                     NaN
# PRB, Mt                                                   NaN
# Ni, %.1                                                   NaN
# Co, %.1                                                   NaN
# MRS, Mt                                                 0.096
# Ni, %.2                                                   4.6
# Co, %.2                                                   NaN
# IND, Mt                                                 0.283
# Ni, %.3                                                     4
# Co, %.3                                                   NaN
# IFR, Mt                                                 0.216
# Ni, %.4                                                   3.4
# Co, %.4                                                   NaN
# Update status                                             NaN
# Reference           http://www.rncminerals.com/beta-hunt-mine
# My Comment                                                NaN
# OPERATING_STATUS                               operating mine
# STATE                                                      WA
# COMMODIDS                                              Ni, Au
# ZONE_ENO                                               339837
# Name: 2, dtype: object
# DEPOSIT_ENO                                            333811
# DEPOSIT_NAME                                        Beta Hunt
# Company                                     ROYAL NICKEL CORP
# ZONE_NAME                                         Beta (Gold)
# Date                                      2016-02-01 00:00:00
# PRV, Mt                                                   NaN
# Ni, %                                                     NaN
# Co, %                                                     NaN
# PRB, Mt                                                   NaN
# Ni, %.1                                                   NaN
# Co, %.1                                                   NaN
# MRS, Mt                                                   NaN
# Ni, %.2                                                   NaN
# Co, %.2                                                   NaN
# IND, Mt                                                 0.815
# Ni, %.3                                                   NaN
# Co, %.3                                                   NaN
# IFR, Mt                                                  2.91
# Ni, %.4                                                   NaN
# Co, %.4                                                   NaN
# Update status                                             NaN
# Reference           http://www.rncminerals.com/beta-hunt-mine
# My Comment                                                NaN
# OPERATING_STATUS                               operating mine
# STATE                                                      WA
# COMMODIDS                                              Ni, Au
# ZONE_ENO                                               600572
# Name: 3, dtype: object
# DEPOSIT_ENO                      334649
# DEPOSIT_NAME                 Black Swan
# Company             Poseidon Nickel Ltd
# ZONE_NAME                    Black Swan
# Date                                NaT
# PRV, Mt                       NO CHANGE
# Ni, %                               NaN
# Co, %                               NaN
# PRB, Mt                             NaN
# Ni, %.1                             NaN
# Co, %.1                             NaN
# MRS, Mt                             NaN
# Ni, %.2                             NaN
# Co, %.2                             NaN
# IND, Mt                             NaN
# Ni, %.3                             NaN
# Co, %.3                             NaN
# IFR, Mt                             NaN
# Ni, %.4                             NaN
# Co, %.4                             NaN
# Update status                 NO CHANGE
# Reference                  ref in OZMIN
# My Comment                          NaN
# OPERATING_STATUS          historic mine
# STATE                                WA
# COMMODIDS                            Ni
# ZONE_ENO                         339287
# Name: 4, dtype: object
# DEPOSIT_ENO                      334649
# DEPOSIT_NAME                 Black Swan
# Company             Poseidon Nickel Ltd
# ZONE_NAME                   Silver Swan
# Date                                NaT
# PRV, Mt                       NO CHANGE
# Ni, %                               NaN
# Co, %                               NaN
# PRB, Mt                             NaN
# Ni, %.1                             NaN
# Co, %.1                             NaN
# MRS, Mt                             NaN
# Ni, %.2                             NaN
# Co, %.2                             NaN
# IND, Mt                             NaN
# Ni, %.3                             NaN
# Co, %.3                             NaN
# IFR, Mt                             NaN
# Ni, %.4                             NaN
# Co, %.4                             NaN
# Update status                 NO CHANGE
# Reference                  ref in OZMIN
# My Comment                          NaN
# OPERATING_STATUS          historic mine
# STATE                                WA
# COMMODIDS                            Ni
# ZONE_ENO                         600555
# Name: 5, dtype: object
# DEPOSIT_ENO                              NaN
# DEPOSIT_NAME                          Bulong
# Company                      Heron Resources
# ZONE_NAME                               East
# Date                     2016-10-27 00:00:00
# PRV, Mt                                  NaN
# Ni, %                                    NaN
# Co, %                                    NaN
# PRB, Mt                                  NaN
# Ni, %.1                                  NaN
# Co, %.1                                  NaN
# MRS, Mt                                  NaN
# Ni, %.2                                  NaN
# Co, %.2                                  NaN
# IND, Mt                                 15.9
# Ni, %.3                                 1.06
# Co, %.3                                0.055
# IFR, Mt                                   24
# Ni, %.4                                 0.79
# Co, %.4                                0.053
# Update status                            NaN
# Reference           Heron Annual Report 2016
# My Comment                               NaN
# OPERATING_STATUS                         NaN
# STATE                                     WA
# COMMODIDS                                NaN
# ZONE_ENO                                 NaN
# Name: 6, dtype: object
# DEPOSIT_ENO                              NaN
# DEPOSIT_NAME                          Bulong
# Company                      Heron Resources
# ZONE_NAME                             Taurus
# Date                     2016-10-27 00:00:00
# PRV, Mt                                  NaN
# Ni, %                                    NaN
# Co, %                                    NaN
# PRB, Mt                                  NaN
# Ni, %.1                                  NaN
# Co, %.1                                  NaN
# MRS, Mt                                  NaN
# Ni, %.2                                  NaN
# Co, %.2                                  NaN
# IND, Mt                                  NaN
# Ni, %.3                                  NaN
# Co, %.3                                  NaN
# IFR, Mt                                 14.2
# Ni, %.4                                 0.84
# Co, %.4                                0.051
# Update status                            NaN
# Reference           Heron Annual Report 2016
# My Comment                               NaN
# OPERATING_STATUS                         NaN
# STATE                                     WA
# COMMODIDS                                NaN
# ZONE_ENO                                 NaN
# Name: 7, dtype: object
# DEPOSIT_ENO                                                 558971
# DEPOSIT_NAME                                               Burnett
# Company                                        Mincor Resources NL
# ZONE_NAME                                     Burnett-MiItel North
# Date                                           2016-06-30 00:00:00
# PRV, Mt                                                        NaN
# Ni, %                                                          NaN
# Co, %                                                          NaN
# PRB, Mt                                                      0.271
# Ni, %.1                                                        2.6
# Co, %.1                                                        NaN
# MRS, Mt                                                        NaN
# Ni, %.2                                                        NaN
# Co, %.2                                                        NaN
# IND, Mt                                                      0.241
# Ni, %.3                                                          4
# Co, %.3                                                        NaN
# IFR, Mt                                                        NaN
# Ni, %.4                                                        NaN
# Co, %.4                                                        NaN
# Update status                                                  NaN
# Reference           Mincor Resources NL Quarterly Report June 2017
# My Comment                                                     NaN
# OPERATING_STATUS                                   mineral deposit
# STATE                                                           WA
# COMMODIDS                                               Ni, Co, Cu
# ZONE_ENO                                                    558972
# Name: 8, dtype: object
# DEPOSIT_ENO                                                    NaN
# DEPOSIT_NAME                                               Cameron
# Company                                        Mincor Resources NL
# ZONE_NAME                                                  Cameron
# Date                                           2016-06-30 00:00:00
# PRV, Mt                                                        NaN
# Ni, %                                                          NaN
# Co, %                                                          NaN
# PRB, Mt                                                        NaN
# Ni, %.1                                                        NaN
# Co, %.1                                                        NaN
# MRS, Mt                                                        NaN
# Ni, %.2                                                        NaN
# Co, %.2                                                        NaN
# IND, Mt                                                      0.096
# Ni, %.3                                                        3.3
# Co, %.3                                                        NaN
# IFR, Mt                                                        NaN
# Ni, %.4                                                        NaN
# Co, %.4                                                        NaN
# Update status                                                  NaN
# Reference           Mincor Resources NL Quarterly Report June 2017
# My Comment                                                     NaN
# OPERATING_STATUS                                   mineral deposit
# STATE                                                           WA
# COMMODIDS                                                       Ni
# ZONE_ENO                                                       NaN
# Name: 9, dtype: object
# DEPOSIT_ENO                                                 333787
# DEPOSIT_NAME                                              Carnilya
# Company                                        Mincor Resources NL
# ZONE_NAME                                            Carnilya Hill
# Date                                           2016-06-30 00:00:00
# PRV, Mt                                                        NaN
# Ni, %                                                          NaN
# Co, %                                                          NaN
# PRB, Mt                                                        NaN
# Ni, %.1                                                        NaN
# Co, %.1                                                        NaN
# MRS, Mt                                                      0.033
# Ni, %.2                                                        3.6
# Co, %.2                                                        NaN
# IND, Mt                                                       0.04
# Ni, %.3                                                        2.2
# Co, %.3                                                        NaN
# IFR, Mt                                                        NaN
# Ni, %.4                                                        NaN
# Co, %.4                                                        NaN
# Update status                                                  NaN
# Reference           Mincor Resources NL Quarterly Report June 2017
# My Comment                                                     NaN
# OPERATING_STATUS                                    operating mine
# STATE                                                           WA
# COMMODIDS                                                   Ni, Cu
# ZONE_ENO                                                    337028
# Name: 10, dtype: object
# DEPOSIT_ENO                                 463677
# DEPOSIT_NAME                              Cerberus
# Company                        Poseidon Nickel Ltd
# ZONE_NAME                                 Cerberus
# Date                                           NaT
# PRV, Mt                           FIGURES IN OZMIN
# Ni, %                                          NaN
# Co, %                                          NaN
# PRB, Mt                                        NaN
# Ni, %.1                                        NaN
# Co, %.1                                        NaN
# MRS, Mt                                        NaN
# Ni, %.2                                        NaN
# Co, %.2                                        NaN
# IND, Mt                                        NaN
# Ni, %.3                                        NaN
# Co, %.3                                        NaN
# IFR, Mt                                        NaN
# Ni, %.4                                        NaN
# Co, %.4                                        NaN
# Update status       Check change compared to OZMIN
# Reference                             ref in OZMIN
# My Comment                                     NaN
# OPERATING_STATUS                   mineral deposit
# STATE                                           WA
# COMMODIDS                       Ni, Co, Cu, Pt, Pd
# ZONE_ENO                                    463678
# Name: 11, dtype: object
# DEPOSIT_ENO                            335342
# DEPOSIT_NAME                     Cliffs (BHP)
# Company                                   BHP
# ZONE_NAME           Cliffs u/g (Disseminated)
# Date                      2016-06-30 00:00:00
# PRV, Mt                                   NaN
# Ni, %                                     NaN
# Co, %                                     NaN
# PRB, Mt                                   NaN
# Ni, %.1                                   NaN
# Co, %.1                                   NaN
# MRS, Mt                                   NaN
# Ni, %.2                                   NaN
# Co, %.2                                   NaN
# IND, Mt                                   NaN
# Ni, %.3                                   NaN
# Co, %.3                                   NaN
# IFR, Mt                                   NaN
# Ni, %.4                                   NaN
# Co, %.4                                   NaN
# Update status                   OZMIN updated
# Reference              BHP 2016 annual report
# My Comment                                NaN
# OPERATING_STATUS               operating mine
# STATE                                      WA
# COMMODIDS                              Ni, Co
# ZONE_ENO                               593585
# Name: 12, dtype: object
# DEPOSIT_ENO                                335342
# DEPOSIT_NAME                         Cliffs (BHP)
# Company                                       BHP
# ZONE_NAME           Cliffs u/g (Massive Sulphide)
# Date                          2016-06-30 00:00:00
# PRV, Mt                                       NaN
# Ni, %                                         NaN
# Co, %                                         NaN
# PRB, Mt                                       NaN
# Ni, %.1                                       NaN
# Co, %.1                                       NaN
# MRS, Mt                                       NaN
# Ni, %.2                                       NaN
# Co, %.2                                       NaN
# IND, Mt                                       NaN
# Ni, %.3                                       NaN
# Co, %.3                                       NaN
# IFR, Mt                                       NaN
# Ni, %.4                                       NaN
# Co, %.4                                       NaN
# Update status                       OZMIN updated
# Reference                  BHP 2016 annual report
# My Comment                                    NaN
# OPERATING_STATUS                   operating mine
# STATE                                          WA
# COMMODIDS                                  Ni, Co
# ZONE_ENO                                   340991
# Name: 13, dtype: object
# DEPOSIT_ENO                                         335908
# DEPOSIT_NAME                                    Copernicus
# Company                                Panoramic Resources
# ZONE_NAME                              Copernicus Open Pit
# Date                                   2016-06-30 00:00:00
# PRV, Mt                                                NaN
# Ni, %                                                  NaN
# Co, %                                                  NaN
# PRB, Mt                                                NaN
# Ni, %.1                                                NaN
# Co, %.1                                                NaN
# MRS, Mt                                              0.132
# Ni, %.2                                               0.97
# Co, %.2                                               0.03
# IND, Mt                                                NaN
# Ni, %.3                                                NaN
# Co, %.3                                                NaN
# IFR, Mt                                                NaN
# Ni, %.4                                                NaN
# Co, %.4                                                NaN
# Update status                                          NaN
# Reference           Panoramic Resources Annual Report 2016
# My Comment                                             NaN
# OPERATING_STATUS                             historic mine
# STATE                                                   WA
# COMMODIDS                                     Ni, Cu, (Co)
# ZONE_ENO                                            341713
# Name: 14, dtype: object
# DEPOSIT_ENO                                         335908
# DEPOSIT_NAME                                    Copernicus
# Company                                Panoramic Resources
# ZONE_NAME                           Copernicus Underground
# Date                                   2016-06-30 00:00:00
# PRV, Mt                                                NaN
# Ni, %                                                  NaN
# Co, %                                                  NaN
# PRB, Mt                                                NaN
# Ni, %.1                                                NaN
# Co, %.1                                                NaN
# MRS, Mt                                                NaN
# Ni, %.2                                                NaN
# Co, %.2                                                NaN
# IND, Mt                                              0.508
# Ni, %.3                                                1.3
# Co, %.3                                                NaN
# IFR, Mt                                              0.025
# Ni, %.4                                               0.98
# Co, %.4                                               0.02
# Update status                                          NaN
# Reference           Panoramic Resources Annual Report 2016
# My Comment                                             NaN
# OPERATING_STATUS                             historic mine
# STATE                                                   WA
# COMMODIDS                                     Ni, Cu, (Co)
# ZONE_ENO                                            600564
# Name: 15, dtype: object
# DEPOSIT_ENO                                      NaN
# DEPOSIT_NAME                              Cosmic Boy
# Company                            Western Areas Ltd
# ZONE_NAME                                 Cosmic Boy
# Date                             2016-06-30 00:00:00
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                       0.1809
# Ni, %.3                                          2.8
# Co, %.3                                          NaN
# IFR, Mt                                          NaN
# Ni, %.4                                          NaN
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                                 NaN
# STATE                                             WA
# COMMODIDS                                         Ni
# ZONE_ENO                                         NaN
# Name: 16, dtype: object
# DEPOSIT_ENO                                   333803
# DEPOSIT_NAME                                  Cosmos
# Company                            Western Areas Ltd
# ZONE_NAME                                 Cosmos AM5
# Date                                             NaT
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                     0.479914
# Ni, %.3                                          2.6
# Co, %.3                                          NaN
# IFR, Mt                                     0.026922
# Ni, %.4                                          1.9
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                       historic mine
# STATE                                             WA
# COMMODIDS              Cu, Ni, (Pt, Pd, Co, PGE, Au)
# ZONE_ENO                                      338712
# Name: 17, dtype: object
# DEPOSIT_ENO                                   333803
# DEPOSIT_NAME                                  Cosmos
# Company                            Western Areas Ltd
# ZONE_NAME                                 Cosmos AM6
# Date                                             NaT
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                      1.70455
# Ni, %.3                                          2.7
# Co, %.3                                          NaN
# IFR, Mt                                     0.329443
# Ni, %.4                                          2.5
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                       historic mine
# STATE                                             WA
# COMMODIDS              Cu, Ni, (Pt, Pd, Co, PGE, Au)
# ZONE_ENO                                      600573
# Name: 18, dtype: object
# DEPOSIT_ENO                                   333803
# DEPOSIT_NAME                                  Cosmos
# Company                            Western Areas Ltd
# ZONE_NAME                         Cosmos Mount Goode
# Date                                             NaT
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                       13.563
# Ni, %.2                                          0.8
# Co, %.2                                          NaN
# IND, Mt                                       27.363
# Ni, %.3                                          0.6
# Co, %.3                                          NaN
# IFR, Mt                                       12.009
# Ni, %.4                                          0.5
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                       historic mine
# STATE                                             WA
# COMMODIDS              Cu, Ni, (Pt, Pd, Co, PGE, Au)
# ZONE_ENO                                      600579
# Name: 19, dtype: object
# DEPOSIT_ENO                                   333803
# DEPOSIT_NAME                                  Cosmos
# Company                            Western Areas Ltd
# ZONE_NAME                            Cosmos Odysseus
# Date                                             NaT
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                      3.88486
# Ni, %.3                                          2.2
# Co, %.3                                          NaN
# IFR, Mt                                     0.169165
# Ni, %.4                                          2.1
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                       historic mine
# STATE                                             WA
# COMMODIDS              Cu, Ni, (Pt, Pd, Co, PGE, Au)
# ZONE_ENO                                      600574
# Name: 20, dtype: object
# DEPOSIT_ENO                                   333803
# DEPOSIT_NAME                                  Cosmos
# Company                            Western Areas Ltd
# ZONE_NAME              Cosmos Odysseus North Massive
# Date                                             NaT
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                     0.048043
# Ni, %.3                                        11.16
# Co, %.3                                          NaN
# IFR, Mt                                          NaN
# Ni, %.4                                          NaN
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                       historic mine
# STATE                                             WA
# COMMODIDS              Cu, Ni, (Pt, Pd, Co, PGE, Au)
# ZONE_ENO                                      600576
# Name: 21, dtype: object
# DEPOSIT_ENO                                     333803
# DEPOSIT_NAME                                    Cosmos
# Company                              Western Areas Ltd
# ZONE_NAME           Cosmos Odysseus North-Disseminated
# Date                                               NaT
# PRV, Mt                                            NaN
# Ni, %                                              NaN
# Co, %                                              NaN
# PRB, Mt                                            NaN
# Ni, %.1                                            NaN
# Co, %.1                                            NaN
# MRS, Mt                                            NaN
# Ni, %.2                                            NaN
# Co, %.2                                            NaN
# IND, Mt                                        1.63149
# Ni, %.3                                            2.8
# Co, %.3                                            NaN
# IFR, Mt                                        1.58617
# Ni, %.4                                            2.2
# Co, %.4                                            NaN
# Update status                                      NaN
# Reference             Western Areas 2016 Annual Report
# My Comment                                         NaN
# OPERATING_STATUS                         historic mine
# STATE                                               WA
# COMMODIDS                Cu, Ni, (Pt, Pd, Co, PGE, Au)
# ZONE_ENO                                        600575
# Name: 22, dtype: object
# DEPOSIT_ENO                                      NaN
# DEPOSIT_NAME                           Diggers Rocks
# Company                            Western Areas Ltd
# ZONE_NAME                          Digger Rocks Core
# Date                             2016-06-30 00:00:00
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                        0.093
# Ni, %.1                                            2
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                       0.0549
# Ni, %.3                                          3.7
# Co, %.3                                          NaN
# IFR, Mt                                       0.1723
# Ni, %.4                                          1.1
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                                 NaN
# STATE                                             WA
# COMMODIDS                                         Ni
# ZONE_ENO                                         NaN
# Name: 23, dtype: object
# DEPOSIT_ENO                                      NaN
# DEPOSIT_NAME                           Diggers Rocks
# Company                            Western Areas Ltd
# ZONE_NAME                          Digger Rocks Halo
# Date                             2016-06-30 00:00:00
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                          NaN
# Ni, %.3                                          NaN
# Co, %.3                                          NaN
# IFR, Mt                                        1.441
# Ni, %.4                                          0.7
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                                 NaN
# STATE                                             WA
# COMMODIDS                                         Ni
# ZONE_ENO                                         NaN
# Name: 24, dtype: object
# DEPOSIT_ENO                                      NaN
# DEPOSIT_NAME                           Diggers Rocks
# Company                            Western Areas Ltd
# ZONE_NAME                        Diggers South _halo
# Date                             2016-06-30 00:00:00
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                          4.8
# Ni, %.3                                          0.7
# Co, %.3                                          NaN
# IFR, Mt                                          NaN
# Ni, %.4                                          NaN
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                                 NaN
# STATE                                             WA
# COMMODIDS                                         Ni
# ZONE_ENO                                         NaN
# Name: 25, dtype: object
# DEPOSIT_ENO                                      NaN
# DEPOSIT_NAME                           Diggers Rocks
# Company                            Western Areas Ltd
# ZONE_NAME                         Diggers South_core
# Date                             2016-06-30 00:00:00
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                        2.016
# Ni, %.1                                          1.4
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                            3
# Ni, %.3                                          1.5
# Co, %.3                                          NaN
# IFR, Mt                                          NaN
# Ni, %.4                                          NaN
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                                 NaN
# STATE                                             WA
# COMMODIDS                                         Ni
# ZONE_ENO                                         NaN
# Name: 26, dtype: object
# DEPOSIT_ENO                                      NaN
# DEPOSIT_NAME                           Diggers Rocks
# Company                            Western Areas Ltd
# ZONE_NAME                                Purple Haze
# Date                             2016-06-30 00:00:00
# PRV, Mt                                          NaN
# Ni, %                                            NaN
# Co, %                                            NaN
# PRB, Mt                                          NaN
# Ni, %.1                                          NaN
# Co, %.1                                          NaN
# MRS, Mt                                          NaN
# Ni, %.2                                          NaN
# Co, %.2                                          NaN
# IND, Mt                                         0.56
# Ni, %.3                                          0.9
# Co, %.3                                          NaN
# IFR, Mt                                          NaN
# Ni, %.4                                          NaN
# Co, %.4                                          NaN
# Update status                                    NaN
# Reference           Western Areas 2016 Annual Report
# My Comment                                       NaN
# OPERATING_STATUS                                 NaN
# STATE                                             WA
# COMMODIDS                                         Ni
# ZONE_ENO                                         NaN
# Name: 27, dtype: object
# DEPOSIT_ENO                           334994
# DEPOSIT_NAME                    Ernest Henry
# Company                     Glencore Xstrata
# ZONE_NAME                        Underground
# Date                                     NaT
# PRV, Mt                                  NaN
# Ni, %                                    NaN
# Co, %                                    NaN
# PRB, Mt                                  NaN
# Ni, %.1                                  NaN
# Co, %.1                                  NaN
# MRS, Mt                                  NaN
# Ni, %.2                                  NaN
# Co, %.2                                  NaN
# IND, Mt                                  NaN
# Ni, %.3                                  NaN
# Co, %.3                                  NaN
# IFR, Mt                                  NaN
# Ni, %.4                                  NaN
# Co, %.4                                  NaN
# Update status                            NaN
# Reference                                NaN
# My Comment                               NaN
# OPERATING_STATUS              operating mine
# STATE                                    QLD
# COMMODIDS           Cu, Au, (Mag, FeOre, Fe)
# ZONE_ENO                              342125
# Name: 28, dtype: object
# DEPOSIT_ENO                                                     NaN
# DEPOSIT_NAME                                             Flying Fox
# Company                                           Western Areas Ltd
# ZONE_NAME                     Flying Fox_Lounge Lizard disseminated
# Date                                            2016-06-30 00:00:00
# PRV, Mt                                                         NaN
# Ni, %                                                           NaN
# Co, %                                                           NaN
# PRB, Mt                                                         NaN
# Ni, %.1                                                         NaN
# Co, %.1                                                         NaN
# MRS, Mt                                                         NaN
# Ni, %.2                                                         NaN
# Co, %.2                                                         NaN
# IND, Mt                                                      4.6252
# Ni, %.3                                                         0.8
# Co, %.3                                                         NaN
# IFR, Mt                                                      0.3578
# Ni, %.4                                                           1
# Co, %.4                                                         NaN
# Update status                                                   NaN
# Reference                          Western Areas 2016 Annual Report
# My Comment          Resources are integrated over a number of zones
# OPERATING_STATUS                                                NaN
# STATE                                                            WA
# COMMODIDS                                                        Ni
# ZONE_ENO                                                        NaN
# Name: 29, dtype: object
# DEPOSIT_ENO                                                  335914
# DEPOSIT_NAME                                             Flying Fox
# Company                                           Western Areas Ltd
# ZONE_NAME                          Flying Fox_Lounge Lizard massive
# Date                                            2016-06-30 00:00:00
# PRV, Mt                                                         NaN
# Ni, %                                                           NaN
# Co, %                                                           NaN
# PRB, Mt                                                     1.20008
# Ni, %.1                                                           4
# Co, %.1                                                         NaN
# MRS, Mt                                                         NaN
# Ni, %.2                                                         NaN
# Co, %.2                                                         NaN
# IND, Mt                                                     1.71219
# Ni, %.3                                                         5.3
# Co, %.3                                                         NaN
# IFR, Mt                                                    0.312737
# Ni, %.4                                                        2.55
# Co, %.4                                                         NaN
# Update status                                                   NaN
# Reference                          Western Areas 2016 Annual Report
# My Comment          Resources are integrated over a number of zones
# OPERATING_STATUS                                     operating mine
# STATE                                                            WA
# COMMODIDS                                                        Ni
# ZONE_ENO                                                     570167
# Name: 30, dtype: object
# DEPOSIT_ENO                                                    NaN
# DEPOSIT_NAME                                              Gellatly
# Company                                        Mincor Resources NL
# ZONE_NAME                                                 Gellatly
# Date                                           2016-06-30 00:00:00
# PRV, Mt                                                        NaN
# Ni, %                                                          NaN
# Co, %                                                          NaN
# PRB, Mt                                                        NaN
# Ni, %.1                                                        NaN
# Co, %.1                                                        NaN
# MRS, Mt                                                        NaN
# Ni, %.2                                                        NaN
# Co, %.2                                                        NaN
# IND, Mt                                                      0.029
# Ni, %.3                                                        3.4
# Co, %.3                                                        NaN
# IFR, Mt                                                        NaN
# Ni, %.4                                                        NaN
# Co, %.4                                                        NaN
# Update status                                                  NaN
# Reference           Mincor Resources NL Quarterly Report June 2017
# My Comment                                                     NaN
# OPERATING_STATUS                                               NaN
# ...
# Name: 101, dtype: object
# DEPOSIT_ENO                      334147
# DEPOSIT_NAME                   Windarra
# Company             Poseidon Nickel Ltd
# ZONE_NAME           Windarra gold tails
# Date                                NaT
# PRV, Mt                 Ni not reported
# Ni, %                               NaN
# Co, %                               NaN
# PRB, Mt                             NaN
# Ni, %.1                             NaN
# Co, %.1                             NaN
# MRS, Mt                             NaN
# Ni, %.2                             NaN
# Co, %.2                             NaN
# IND, Mt                             NaN
# Ni, %.3                             NaN
# Co, %.3                             NaN
# IFR, Mt                             NaN
# Ni, %.4                             NaN
# Co, %.4                             NaN
# Update status           Ni not reported
# Reference                             ?
# My Comment                          NaN
# OPERATING_STATUS      under development
# STATE                                WA
# COMMODIDS                    Cu, Ni, Au
# ZONE_ENO                         600550
# Name: 102, dtype: object
# DEPOSIT_ENO                                                    334378
# DEPOSIT_NAME                                    Wingellina (Metals X)
# Company                                              Metals X Limited
# ZONE_NAME                                                  Wingellina
# Date                                                              NaT
# PRV, Mt                                                           NaN
# Ni, %                                                             NaN
# Co, %                                                             NaN
# PRB, Mt                                                           NaN
# Ni, %.1                                                           NaN
# Co, %.1                                                           NaN
# MRS, Mt                                                           NaN
# Ni, %.2                                                           NaN
# Co, %.2                                                           NaN
# IND, Mt                                                           NaN
# Ni, %.3                                                           NaN
# Co, %.3                                                           NaN
# IFR, Mt                                                           NaN
# Ni, %.4                                                           NaN
# Co, %.4                                                           NaN
# Update status                                       Updated by Daisy?
# Reference           Metals X Limited Mineral Resource and Ore Rese...
# My Comment                                                        NaN
# OPERATING_STATUS                                      mineral deposit
# STATE                                                              WA
# COMMODIDS                                 Ni, FeOre, Co, (Fe, Pt, Pd)
# ZONE_ENO                                                       339088
# Name: 103, dtype: object
# DEPOSIT_ENO                            NaN
# DEPOSIT_NAME                    Yakabindie
# Company                                BHP
# ZONE_NAME                              NaN
# Date                   2016-06-30 00:00:00
# PRV, Mt                          NO CHANGE
# Ni, %                                  NaN
# Co, %                                  NaN
# PRB, Mt                                NaN
# Ni, %.1                                NaN
# Co, %.1                                NaN
# MRS, Mt                                NaN
# Ni, %.2                                NaN
# Co, %.2                                NaN
# IND, Mt                                NaN
# Ni, %.3                                NaN
# Co, %.3                                NaN
# IFR, Mt                                NaN
# Ni, %.4                                NaN
# Co, %.4                                NaN
# Update status                    NO CHANGE
# Reference           BHP 2016 annual report
# My Comment                             NaN
# OPERATING_STATUS                       NaN
# STATE                                  NaN
# COMMODIDS                              NaN
# ZONE_ENO                               NaN
# Name: 104, dtype: object
# DEPOSIT_ENO                              NaN
# DEPOSIT_NAME                         Yerilla
# Company                      Heron Resources
# ZONE_NAME                             Aubils
# Date                     2016-10-27 00:00:00
# PRV, Mt                                  NaN
# Ni, %                                    NaN
# Co, %                                    NaN
# PRB, Mt                                  NaN
# Ni, %.1                                  NaN
# Co, %.1                                  NaN
# MRS, Mt                                  3.8
# Ni, %.2                                 0.94
# Co, %.2                                0.048
# IND, Mt                                 41.6
# Ni, %.3                                 0.79
# Co, %.3                                0.043
# IFR, Mt                                 18.4
# Ni, %.4                                 0.64
# Co, %.4                                0.034
# Update status                            NaN
# Reference           Heron Annual Report 2016
# My Comment                               NaN
# OPERATING_STATUS                         NaN
# STATE                                     WA
# COMMODIDS                                NaN
# ZONE_ENO                                 NaN
# Name: 105, dtype: object
# DEPOSIT_ENO                              NaN
# DEPOSIT_NAME                         Yerilla
# Company                      Heron Resources
# ZONE_NAME                        Boyce Creek
# Date                     2016-10-27 00:00:00
# PRV, Mt                                  NaN
# Ni, %                                    NaN
# Co, %                                    NaN
# PRB, Mt                                  NaN
# Ni, %.1                                  NaN
# Co, %.1                                  NaN
# MRS, Mt                                  NaN
# Ni, %.2                                  NaN
# Co, %.2                                  NaN
# IND, Mt                                 26.8
# Ni, %.3                                 0.77
# Co, %.3                                0.058
# IFR, Mt                                  NaN
# Ni, %.4                                  NaN
# Co, %.4                                  NaN
# Update status                            NaN
# Reference           Heron Annual Report 2016
# My Comment                               NaN
# OPERATING_STATUS                         NaN
# STATE                                     WA
# COMMODIDS                                NaN
# ZONE_ENO                                 NaN
# Name: 106, dtype: object
# DEPOSIT_ENO                              NaN
# DEPOSIT_NAME                         Yerilla
# Company                      Heron Resources
# ZONE_NAME                        Jump Up Dam
# Date                     2016-10-27 00:00:00
# PRV, Mt                                  NaN
# Ni, %                                    NaN
# Co, %                                    NaN
# PRB, Mt                                  NaN
# Ni, %.1                                  NaN
# Co, %.1                                  NaN
# MRS, Mt                                  NaN
# Ni, %.2                                  NaN
# Co, %.2                                  NaN
# IND, Mt                                  NaN
# Ni, %.3                                  NaN
# Co, %.3                                  NaN
# IFR, Mt                                   75
# Ni, %.4                                 0.73
# Co, %.4                                0.044
# Update status                            NaN
# Reference           Heron Annual Report 2016
# My Comment                               NaN
# OPERATING_STATUS                         NaN
# STATE                                     WA
# COMMODIDS                                NaN
# ZONE_ENO                                 NaN
# Name: 107, dtype: object
# DEPOSIT_ENO                                           334753
# DEPOSIT_NAME                                Young Australian
# Company                    Queensland Mining Corporation Ltd
# ZONE_NAME                                   Young Australian
# Date                                                     NaT
# PRV, Mt                                                  NaN
# Ni, %                                                    NaN
# Co, %                                                    NaN
# PRB, Mt                                                  NaN
# Ni, %.1                                                  NaN
# Co, %.1                                                  NaN
# MRS, Mt                                                  NaN
# Ni, %.2                                                  NaN
# Co, %.2                                                  NaN
# IND, Mt                                                  NaN
# Ni, %.3                                                  NaN
# Co, %.3                                                  NaN
# IFR, Mt                                                  NaN
# Ni, %.4                                                  NaN
# Co, %.4                                                  NaN
# Update status                                            NaN
# Reference           Young Australian Mineral Resource Update
# My Comment                                               NaN
# OPERATING_STATUS                               historic mine
# STATE                                                    QLD
# COMMODIDS                                       Cu, (Co, Ag)
# ZONE_ENO                                              336337
# Name: 108, dtype: object
# DEPOSIT_ENO                                                    334523
# DEPOSIT_NAME                            Young Nickel (Jervois Mining)
# Company                                        Jervois Mining Limited
# ZONE_NAME                                      Young (0.6%Ni cut off)
# Date                                                              NaT
# PRV, Mt                                                           NaN
# Ni, %                                                             NaN
# Co, %                                                             NaN
# PRB, Mt                                                           NaN
# Ni, %.1                                                           NaN
# Co, %.1                                                           NaN
# MRS, Mt                                                           NaN
# Ni, %.2                                                           NaN
# Co, %.2                                                           NaN
# IND, Mt                                                           NaN
# Ni, %.3                                                           NaN
# Co, %.3                                                           NaN
# IFR, Mt                                                           NaN
# Ni, %.4                                                           NaN
# Co, %.4                                                           NaN
# Update status                                                     NaN
# Reference           EL's5527 and 5571 Young Ni Co Project - Decemb...
# My Comment                                                        NaN
# OPERATING_STATUS                                      mineral deposit
# STATE                                                             NSW
# COMMODIDS                                                      Ni, Co
# ZONE_ENO                                                       342361
# Name: 109, dtype: object
# DEPOSIT_ENO                          NaN
# DEPOSIT_NAME                         NaN
# Company                              NaN
# ZONE_NAME           Disseminated sulfide
# Date                 2016-06-30 00:00:00
# PRV, Mt                              NaN
# Ni, %                                NaN
# Co, %                                NaN
# PRB, Mt                              NaN
# Ni, %.1                              NaN
# Co, %.1                              NaN
# MRS, Mt                              NaN
# Ni, %.2                              NaN
# Co, %.2                              NaN
# IND, Mt                              NaN
# Ni, %.3                              NaN
# Co, %.3                              NaN
# IFR, Mt                              NaN
# Ni, %.4                              NaN
# Co, %.4                              NaN
# Update status              OZMIN updated
# Reference                            NaN
# My Comment                           NaN
# OPERATING_STATUS                     NaN
# STATE                                NaN
# COMMODIDS                            NaN
# ZONE_ENO                             NaN
# Name: 110, dtype: object
# DEPOSIT_ENO                         NaN
# DEPOSIT_NAME                        NaN
# Company                             NaN
# ZONE_NAME                            SP
# Date                2016-06-30 00:00:00
# PRV, Mt                             NaN
# Ni, %                               NaN
# Co, %                               NaN
# PRB, Mt                             NaN
# Ni, %.1                             NaN
# Co, %.1                             NaN
# MRS, Mt                             NaN
# Ni, %.2                             NaN
# Co, %.2                             NaN
# IND, Mt                             NaN
# Ni, %.3                             NaN
# Co, %.3                             NaN
# IFR, Mt                             NaN
# Ni, %.4                             NaN
# Co, %.4                             NaN
# Update status             OZMIN updated
# Reference                           NaN
# My Comment                          NaN
# OPERATING_STATUS                    NaN
# STATE                               NaN
# COMMODIDS                           NaN
# ZONE_ENO                            NaN
# Name: 111, dtype: object
# DEPOSIT_ENO                         NaN
# DEPOSIT_NAME                        NaN
# Company                             NaN
# ZONE_NAME                   SP Oxidised
# Date                2016-06-30 00:00:00
# PRV, Mt                             NaN
# Ni, %                               NaN
# Co, %                               NaN
# PRB, Mt                             NaN
# Ni, %.1                             NaN
# Co, %.1                             NaN
# MRS, Mt                             NaN
# Ni, %.2                             NaN
# Co, %.2                             NaN
# IND, Mt                             NaN
# Ni, %.3                             NaN
# Co, %.3                             NaN
# IFR, Mt                             NaN
# Ni, %.4                             NaN
# Co, %.4                             NaN
# Update status             OZMIN updated
# Reference                           NaN
# My Comment                          NaN
# OPERATING_STATUS                    NaN
# STATE                               NaN
# COMMODIDS                           NaN
# ZONE_ENO                            NaN
# Name: 112, dtype: object
# DEPOSIT_ENO                         NaN
# DEPOSIT_NAME                        NaN
# Company                             NaN
# ZONE_NAME                            UG
# Date                2016-06-30 00:00:00
# PRV, Mt                             NaN
# Ni, %                               NaN
# Co, %                               NaN
# PRB, Mt                             NaN
# Ni, %.1                             NaN
# Co, %.1                             NaN
# MRS, Mt                             NaN
# Ni, %.2                             NaN
# Co, %.2                             NaN
# IND, Mt                             NaN
# Ni, %.3                             NaN
# Co, %.3                             NaN
# IFR, Mt                             NaN
# Ni, %.4                             NaN
# Co, %.4                             NaN
# Update status             OZMIN updated
# Reference                           NaN
# My Comment                          NaN
# OPERATING_STATUS                    NaN
# STATE                               NaN
# COMMODIDS                           NaN
# ZONE_ENO                            NaN
# Name: 113, dtype: object
